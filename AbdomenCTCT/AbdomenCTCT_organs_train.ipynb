# %%
# !nvidia-smi
# Out:
# Tue Aug 13 14:14:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0              31W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Setup

# %%
# install tensorflow 2.15 since voxelmorph is not compatible with current build
import tensorflow as tf
if not tf.__version__.startswith('2.15'):
  # !pip uninstall -y tensorflow
  # !pip install tensorflow==2.15
# install voxelmorph
# !pip install voxelmorph
# Out:
# Requirement already satisfied: voxelmorph in /usr/local/lib/python3.10/dist-packages (0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (24.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.23.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (3.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.13.1)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (5.0.1)
# Requirement already satisfied: neurite>=0.2 in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.3.2)
# Requirement already satisfied: pystrum>=0.2 in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->voxelmorph) (71.0.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (3.3)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (9.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2024.7.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (3.5.0)

# %%
import voxelmorph as vxm
import neurite as ne

import os
import urllib.request
import zipfile
import json
import nibabel as nib
import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split

# %% [markdown]
# # Download dataset

# %%
# download dataset
filename = 'AbdomenCTCT.zip'
if not os.path.exists(filename):
    url = 'https://cloud.imi.uni-luebeck.de/s/32WaSRaTnFk2JeT/download/AbdomenCTCT.zip'
    urllib.request.urlretrieve(url, filename)

    # extract files
    with zipfile.ZipFile(filename, 'r') as zip_ref:
        zip_ref.extractall('./')

# %%
def load_data(jsonData, dataFolderPath, training_or_test, filterString='0001'):
    images = []
    labels = []
    for sample in jsonData[training_or_test]:
        image = nib.load(dataFolderPath + sample['image'].removeprefix('.').replace(".csv",".nii.gz")).get_fdata()
        images.append(image)
        if training_or_test == 'training':
          label = nib.load(dataFolderPath + sample['label'].removeprefix('.').replace(".csv",".nii.gz")).get_fdata()
          labels.append(label)

    return np.array(images), np.array(labels)

# %%
# load data
with open('./AbdomenCTCT/AbdomenCTCT_dataset.json', 'r') as file:
  data_json = json.load(file)
dataFolder = './AbdomenCTCT'
images_raw, labels_raw = load_data(data_json, dataFolder, 'training')

# %%
images_raw.shape
# Out:
# (30, 192, 160, 256)

# %%
labels_raw.shape
# Out:
# (30, 192, 160, 256)

# %% [markdown]
# # Preprocess data

# %%
# normalize images
images_normalized = (images_raw - np.min(images_raw)) / (np.max(images_raw) - np.min(images_raw))

# rotate tensor
images_rotated = np.array([np.rot90(image, k=1, axes=(0, 2)) for image in images_normalized])
labels_rotated = np.array([np.rot90(image, k=1, axes=(0, 2)) for image in labels_raw])

# swap and flip axes
images = np.swapaxes(images_rotated, 1, 2)[:, ::-1, :, :]
labels = np.swapaxes(labels_rotated, 1, 2)[:, ::-1, :, :]

# prepare tensor just with organs
organs = np.zeros_like(images)
organs[labels > 0] = images[labels > 0]

# %%
del images_raw
del labels_raw
del images_normalized
del images_rotated
del labels_rotated

# %%
# preview data
img = 0
depth = 40

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(16,8))
ax0.imshow(images[img,depth],cmap='gray')
ax0.set_title("Image")
ax0.axis("off")
ax1.imshow(labels[img,depth], cmap='gray')
ax1.set_title("Labels")
ax1.axis("off")
ax2.imshow(organs[img,depth], cmap='gray')
ax2.set_title("Organs")
ax2.axis("off")
# Out:
# (-0.5, 191.5, 255.5, -0.5)

# %%
# split dataset
training_organs, _ = train_test_split(organs, test_size=0.2, random_state=10)

# %%
del images
del labels
del organs
del _

# %%
training_organs.shape
# Out:
# (24, 160, 256, 192)

# %% [markdown]
# # Define Model

# %%
# Define the input shapes
inshape = training_organs.shape[1:]
nb_features = (
    (16, 32, 32), # encoder-channels
    (32, 32, 16, 16) # decoder-channels
    )

# build model using VxmDense
vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)

print('input shape: ', ', '.join([str(t.shape) for t in vxm_model.inputs]))
print('output shape:', ', '.join([str(t.shape) for t in vxm_model.outputs]))
# Out:
# input shape:  (None, 160, 256, 192, 1), (None, 160, 256, 192, 1)
# output shape: (None, 160, 256, 192, 1), (None, 160, 256, 192, 3)

# %% [markdown]
# # Train model

# %%
# define loss functions
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]

# balance the two losses with hyper-parameter
lambda_param = 0.05
loss_weights = [1, lambda_param]

# %%
# compile model
vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %%
# define a data generator
def training_data_generator(data, batch_size):
    vol_shape = data.shape[1:]
    ndims = len(vol_shape)

    # prepare a zero array the size of the deformation
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])

    while True:
        idx1 = np.random.randint(0, data.shape[0], size=batch_size)
        idx2 = np.random.randint(0, data.shape[0], size=batch_size)

        fixed_image = data[idx1, ..., np.newaxis]
        moving_image = data[idx2, ..., np.newaxis]

        inputs = [moving_image, fixed_image]
        outputs = [fixed_image, zero_phi]

        yield (inputs, outputs)

# %%
batch_size = 2

# define training generator
train_generator = training_data_generator(training_organs, batch_size=batch_size)
in_sample, out_sample = next(train_generator)

# view generated data
images = [img[0, depth, :, :] for img in in_sample + out_sample]
titles = ['moved', 'fixed', 'moved ground-truth (fixed)', 'zeros']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
# train model
nb_epochs = 50
steps_per_epoch = 10
hist = vxm_model.fit(
    train_generator,
    epochs=nb_epochs,
    steps_per_epoch=steps_per_epoch,
    verbose=1
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 113s 3s/step - loss: 0.0035 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 1.7860e-04
# Epoch 2/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0036 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 2.8482e-04
# Epoch 3/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0027 - vxm_dense_transformer_loss: 0.0026 - vxm_dense_flow_loss: 0.0017
# Epoch 4/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0032 - vxm_dense_transformer_loss: 0.0030 - vxm_dense_flow_loss: 0.0043
# Epoch 5/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0022 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0044
# Epoch 6/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0021 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0043
# Epoch 7/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0021 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0065
# Epoch 8/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0022 - vxm_dense_transformer_loss: 0.0019 - vxm_dense_flow_loss: 0.0056
# Epoch 9/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0020 - vxm_dense_transformer_loss: 0.0017 - vxm_dense_flow_loss: 0.0056
# Epoch 10/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0016 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0062
# Epoch 11/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0070
# Epoch 12/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0020 - vxm_dense_transformer_loss: 0.0016 - vxm_dense_flow_loss: 0.0079
# Epoch 13/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0081
# Epoch 14/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0073
# Epoch 15/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0079
# Epoch 16/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0092
# Epoch 17/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0098
# Epoch 18/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0019 - vxm_dense_transformer_loss: 0.0015 - vxm_dense_flow_loss: 0.0087
# Epoch 19/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0077
# Epoch 20/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0084
# Epoch 21/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0094
# Epoch 22/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0092
# Epoch 23/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0019 - vxm_dense_transformer_loss: 0.0014 - vxm_dense_flow_loss: 0.0094
# Epoch 24/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0016 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0082
# Epoch 25/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0013 - vxm_dense_transformer_loss: 9.5728e-04 - vxm_dense_flow_loss: 0.0077
# Epoch 26/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0013 - vxm_dense_transformer_loss: 9.6314e-04 - vxm_dense_flow_loss: 0.0075
# Epoch 27/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0014 - vxm_dense_transformer_loss: 9.5354e-04 - vxm_dense_flow_loss: 0.0084
# Epoch 28/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0014 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0082
# Epoch 29/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0100
# Epoch 30/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0081
# Epoch 31/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0016 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0091
# Epoch 32/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0089
# Epoch 33/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0104
# Epoch 34/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0016 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0085
# Epoch 35/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0013 - vxm_dense_transformer_loss: 9.4323e-04 - vxm_dense_flow_loss: 0.0081
# Epoch 36/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0018 - vxm_dense_transformer_loss: 0.0013 - vxm_dense_flow_loss: 0.0102
# Epoch 37/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0089
# Epoch 38/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0013 - vxm_dense_transformer_loss: 9.5922e-04 - vxm_dense_flow_loss: 0.0076
# Epoch 39/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0086
# Epoch 40/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0090
# Epoch 41/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0075
# Epoch 42/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0014 - vxm_dense_transformer_loss: 9.7134e-04 - vxm_dense_flow_loss: 0.0089
# Epoch 43/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0012 - vxm_dense_transformer_loss: 8.0710e-04 - vxm_dense_flow_loss: 0.0070
# Epoch 44/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0094
# Epoch 45/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0017 - vxm_dense_transformer_loss: 0.0012 - vxm_dense_flow_loss: 0.0099
# Epoch 46/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0016 - vxm_dense_transformer_loss: 0.0011 - vxm_dense_flow_loss: 0.0099
# Epoch 47/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0012 - vxm_dense_transformer_loss: 7.9465e-04 - vxm_dense_flow_loss: 0.0081
# Epoch 48/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 9.9341e-04 - vxm_dense_flow_loss: 0.0094
# Epoch 49/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0093
# Epoch 50/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0015 - vxm_dense_transformer_loss: 0.0010 - vxm_dense_flow_loss: 0.0088

# %%
# extract train-loss
train_loss = hist.history['loss']

# plot history
plt.figure(figsize=(12, 6))
plt.plot(range(1, nb_epochs + 1), train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training Loss')
plt.show()

# %% [markdown]
# # Save model

# %%
if not os.path.exists('models'):
    os.makedirs('models')
vxm_model.save_weights('models/AbdomenCTCT_organs_model.h5')
