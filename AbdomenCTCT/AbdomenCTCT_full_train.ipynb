# %%
# !nvidia-smi
# Out:
# Mon Aug 12 10:48:00 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # Setup

# %%
# install tensorflow 2.15 since voxelmorph is not compatible with current build
import tensorflow as tf
if not tf.__version__.startswith('2.15'):
  # !pip uninstall -y tensorflow
  # !pip install tensorflow==2.15
# install voxelmorph
# !pip install voxelmorph
# Out:
# Collecting voxelmorph
#   Using cached voxelmorph-0.2-py3-none-any.whl.metadata (660 bytes)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (24.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (0.23.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (3.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (1.13.1)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (from voxelmorph) (5.0.1)
# Collecting neurite>=0.2 (from voxelmorph)
#   Using cached neurite-0.2-py3-none-any.whl.metadata (653 bytes)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (4.66.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from neurite>=0.2->voxelmorph) (1.3.2)
# Collecting pystrum>=0.2 (from neurite>=0.2->voxelmorph)
#   Using cached pystrum-0.4-py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nibabel->voxelmorph) (71.0.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (3.3)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (9.4.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (2024.7.24)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->voxelmorph) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->neurite>=0.2->voxelmorph) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->neurite>=0.2->voxelmorph) (3.5.0)
# Using cached voxelmorph-0.2-py3-none-any.whl (54 kB)
# Using cached neurite-0.2-py3-none-any.whl (108 kB)
# Installing collected packages: pystrum, neurite, voxelmorph
# Successfully installed neurite-0.2 pystrum-0.4 voxelmorph-0.2

# %%
import voxelmorph as vxm
import neurite as ne

import os
import urllib.request
import zipfile
import json
import nibabel as nib
import matplotlib.pyplot as plt
from matplotlib import colors, patches
import numpy as np

# %% [markdown]
# # Download dataset

# %%
# download dataset
filename = 'AbdomenCTCT.zip'
if not os.path.exists(filename):
    url = 'https://cloud.imi.uni-luebeck.de/s/32WaSRaTnFk2JeT/download/AbdomenCTCT.zip'
    urllib.request.urlretrieve(url, filename)

    # extract files
    with zipfile.ZipFile(filename, 'r') as zip_ref:
        zip_ref.extractall('./')

# %%
def load_data(jsonData, dataFolderPath, training_or_test, filterString='0001'):
    images = []
    for sample in jsonData[training_or_test]:
        image = nib.load(dataFolderPath + sample['image'].removeprefix('.')).get_fdata()
        images.append(image)

    return np.array(images)

# %%
# load data
with open('./AbdomenCTCT/AbdomenCTCT_dataset.json', 'r') as file:
  data_json = json.load(file)
dataFolder = './AbdomenCTCT'
training_images_raw = load_data(data_json, dataFolder, 'training')

# %%
training_images_raw.shape
# Out:
# (30, 192, 160, 256)

# %% [markdown]
# # Preprocess data

# %%
# normalize images
training_images_normalized = (training_images_raw - np.min(training_images_raw)) / (np.max(training_images_raw) - np.min(training_images_raw))

# rotate tensor
training_images_rotated = np.array([np.rot90(image, k=1, axes=(0, 2)) for image in training_images_normalized])

# swap and flip axes
training_images = np.swapaxes(training_images_rotated, 1, 2)[:, ::-1, :, :]

del training_images_raw
del training_images_normalized
del training_images_rotated

# %%
training_images.shape
# Out:
# (30, 160, 256, 192)

# %%
# preview data
img = 0
depth = 40

plt.imshow(training_images[img,depth],cmap='gray')

# %% [markdown]
# # Define Model

# %%
# Define the input shapes
inshape = training_images.shape[1:]
nb_features = (
    (16, 32, 32), # encoder-channels
    (32, 32, 16) # decoder-channels
    )

# build model using VxmDense
vxm_model = vxm.networks.VxmDense(inshape, nb_features, int_steps=0)

print('input shape: ', ', '.join([str(t.shape) for t in vxm_model.inputs]))
print('output shape:', ', '.join([str(t.shape) for t in vxm_model.outputs]))
# Out:
# input shape:  (None, 160, 256, 192, 1), (None, 160, 256, 192, 1)
# output shape: (None, 160, 256, 192, 1), (None, 160, 256, 192, 3)

# %%
# define loss functions
losses = [vxm.losses.MSE().loss, vxm.losses.Grad('l2').loss]

# balance the two losses with hyper-parameter
lambda_param = 0.05
loss_weights = [1, lambda_param]

# %%
# compile model
vxm_model.compile(optimizer='Adam', loss=losses, loss_weights=loss_weights)

# %% [markdown]
# # Train model

# %%
# define a data generator
def training_data_generator(data, batch_size):
    vol_shape = data.shape[1:]
    ndims = len(vol_shape)

    # prepare a zero array the size of the deformation
    zero_phi = np.zeros([batch_size, *vol_shape, ndims])

    while True:
        idx1 = np.random.randint(0, data.shape[0], size=batch_size)
        idx2 = np.random.randint(0, data.shape[0], size=batch_size)

        fixed_image = data[idx1, ..., np.newaxis]
        moving_image = data[idx2, ..., np.newaxis]

        inputs = [moving_image, fixed_image]
        outputs = [fixed_image, zero_phi]

        yield (inputs, outputs)

# %%
batch_size = 2

# define training generator
train_generator = training_data_generator(training_images, batch_size=batch_size)
in_sample, out_sample = next(train_generator)

# view generated data
images = [img[0, depth, :, :] for img in in_sample + out_sample]
titles = ['moved', 'fixed', 'moved ground-truth (fixed)', 'zeros']
ne.plot.slices(images, titles=titles, cmaps=['gray'], do_colorbars=True);

# %%
# train model
nb_epochs = 50
steps_per_epoch = 10
hist = vxm_model.fit(
    train_generator,
    epochs=nb_epochs,
    steps_per_epoch=steps_per_epoch,
    verbose=1
)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 151s 13s/step - loss: 0.0084 - vxm_dense_transformer_loss: 0.0084 - vxm_dense_flow_loss: 1.4844e-04
# Epoch 2/50
# 10/10 [==============================] - 74s 7s/step - loss: 0.0086 - vxm_dense_transformer_loss: 0.0086 - vxm_dense_flow_loss: 3.9152e-04
# Epoch 3/50
# 10/10 [==============================] - 70s 7s/step - loss: 0.0086 - vxm_dense_transformer_loss: 0.0085 - vxm_dense_flow_loss: 0.0019
# Epoch 4/50
# 10/10 [==============================] - 57s 6s/step - loss: 0.0081 - vxm_dense_transformer_loss: 0.0077 - vxm_dense_flow_loss: 0.0080
# Epoch 5/50
# 10/10 [==============================] - 51s 5s/step - loss: 0.0073 - vxm_dense_transformer_loss: 0.0068 - vxm_dense_flow_loss: 0.0102
# Epoch 6/50
# 10/10 [==============================] - 43s 4s/step - loss: 0.0073 - vxm_dense_transformer_loss: 0.0064 - vxm_dense_flow_loss: 0.0184
# Epoch 7/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.0076 - vxm_dense_transformer_loss: 0.0067 - vxm_dense_flow_loss: 0.0185
# Epoch 8/50
# 10/10 [==============================] - 42s 4s/step - loss: 0.0069 - vxm_dense_transformer_loss: 0.0059 - vxm_dense_flow_loss: 0.0201
# Epoch 9/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.0059 - vxm_dense_transformer_loss: 0.0050 - vxm_dense_flow_loss: 0.0183
# Epoch 10/50
# 10/10 [==============================] - 33s 3s/step - loss: 0.0058 - vxm_dense_transformer_loss: 0.0049 - vxm_dense_flow_loss: 0.0170
# Epoch 11/50
# 10/10 [==============================] - 41s 4s/step - loss: 0.0065 - vxm_dense_transformer_loss: 0.0055 - vxm_dense_flow_loss: 0.0207
# Epoch 12/50
# 10/10 [==============================] - 37s 4s/step - loss: 0.0062 - vxm_dense_transformer_loss: 0.0051 - vxm_dense_flow_loss: 0.0213
# Epoch 13/50
# 10/10 [==============================] - 38s 4s/step - loss: 0.0058 - vxm_dense_transformer_loss: 0.0047 - vxm_dense_flow_loss: 0.0217
# Epoch 14/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.0054 - vxm_dense_transformer_loss: 0.0045 - vxm_dense_flow_loss: 0.0179
# Epoch 15/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0066 - vxm_dense_transformer_loss: 0.0058 - vxm_dense_flow_loss: 0.0176
# Epoch 16/50
# 10/10 [==============================] - 34s 3s/step - loss: 0.0057 - vxm_dense_transformer_loss: 0.0047 - vxm_dense_flow_loss: 0.0198
# Epoch 17/50
# 10/10 [==============================] - 31s 3s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0043 - vxm_dense_flow_loss: 0.0199
# Epoch 18/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0050 - vxm_dense_transformer_loss: 0.0040 - vxm_dense_flow_loss: 0.0192
# Epoch 19/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0056 - vxm_dense_transformer_loss: 0.0045 - vxm_dense_flow_loss: 0.0221
# Epoch 20/50
# 10/10 [==============================] - 25s 2s/step - loss: 0.0051 - vxm_dense_transformer_loss: 0.0041 - vxm_dense_flow_loss: 0.0216
# Epoch 21/50
# 10/10 [==============================] - 28s 3s/step - loss: 0.0056 - vxm_dense_transformer_loss: 0.0046 - vxm_dense_flow_loss: 0.0210
# Epoch 22/50
# 10/10 [==============================] - 25s 3s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0043 - vxm_dense_flow_loss: 0.0213
# Epoch 23/50
# 10/10 [==============================] - 24s 2s/step - loss: 0.0055 - vxm_dense_transformer_loss: 0.0044 - vxm_dense_flow_loss: 0.0220
# Epoch 24/50
# 10/10 [==============================] - 34s 4s/step - loss: 0.0048 - vxm_dense_transformer_loss: 0.0038 - vxm_dense_flow_loss: 0.0208
# Epoch 25/50
# 10/10 [==============================] - 38s 4s/step - loss: 0.0063 - vxm_dense_transformer_loss: 0.0052 - vxm_dense_flow_loss: 0.0228
# Epoch 26/50
# 10/10 [==============================] - 32s 3s/step - loss: 0.0051 - vxm_dense_transformer_loss: 0.0040 - vxm_dense_flow_loss: 0.0222
# Epoch 27/50
# 10/10 [==============================] - 24s 2s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0041 - vxm_dense_flow_loss: 0.0238
# Epoch 28/50
# 10/10 [==============================] - 26s 3s/step - loss: 0.0052 - vxm_dense_transformer_loss: 0.0038 - vxm_dense_flow_loss: 0.0267
# Epoch 29/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0055 - vxm_dense_transformer_loss: 0.0042 - vxm_dense_flow_loss: 0.0248
# Epoch 30/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0056 - vxm_dense_transformer_loss: 0.0043 - vxm_dense_flow_loss: 0.0273
# Epoch 31/50
# 10/10 [==============================] - 24s 2s/step - loss: 0.0061 - vxm_dense_transformer_loss: 0.0048 - vxm_dense_flow_loss: 0.0267
# Epoch 32/50
# 10/10 [==============================] - 30s 3s/step - loss: 0.0046 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 0.0213
# Epoch 33/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0044 - vxm_dense_transformer_loss: 0.0034 - vxm_dense_flow_loss: 0.0204
# Epoch 34/50
# 10/10 [==============================] - 30s 3s/step - loss: 0.0048 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 0.0251
# Epoch 35/50
# 10/10 [==============================] - 28s 3s/step - loss: 0.0042 - vxm_dense_transformer_loss: 0.0032 - vxm_dense_flow_loss: 0.0209
# Epoch 36/50
# 10/10 [==============================] - 27s 3s/step - loss: 0.0047 - vxm_dense_transformer_loss: 0.0034 - vxm_dense_flow_loss: 0.0254
# Epoch 37/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0041 - vxm_dense_flow_loss: 0.0235
# Epoch 38/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0047 - vxm_dense_transformer_loss: 0.0038 - vxm_dense_flow_loss: 0.0195
# Epoch 39/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0057 - vxm_dense_transformer_loss: 0.0045 - vxm_dense_flow_loss: 0.0244
# Epoch 40/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0045 - vxm_dense_transformer_loss: 0.0035 - vxm_dense_flow_loss: 0.0214
# Epoch 41/50
# 10/10 [==============================] - 21s 2s/step - loss: 0.0064 - vxm_dense_transformer_loss: 0.0049 - vxm_dense_flow_loss: 0.0309
# Epoch 42/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0052 - vxm_dense_transformer_loss: 0.0039 - vxm_dense_flow_loss: 0.0256
# Epoch 43/50
# 10/10 [==============================] - 24s 2s/step - loss: 0.0052 - vxm_dense_transformer_loss: 0.0038 - vxm_dense_flow_loss: 0.0266
# Epoch 44/50
# 10/10 [==============================] - 24s 2s/step - loss: 0.0048 - vxm_dense_transformer_loss: 0.0036 - vxm_dense_flow_loss: 0.0244
# Epoch 45/50
# 10/10 [==============================] - 25s 3s/step - loss: 0.0056 - vxm_dense_transformer_loss: 0.0043 - vxm_dense_flow_loss: 0.0265
# Epoch 46/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0050 - vxm_dense_transformer_loss: 0.0037 - vxm_dense_flow_loss: 0.0260
# Epoch 47/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0040 - vxm_dense_flow_loss: 0.0262
# Epoch 48/50
# 10/10 [==============================] - 23s 2s/step - loss: 0.0053 - vxm_dense_transformer_loss: 0.0041 - vxm_dense_flow_loss: 0.0251
# Epoch 49/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0047 - vxm_dense_transformer_loss: 0.0036 - vxm_dense_flow_loss: 0.0216
# Epoch 50/50
# 10/10 [==============================] - 22s 2s/step - loss: 0.0046 - vxm_dense_transformer_loss: 0.0034 - vxm_dense_flow_loss: 0.0233

# %%
# extract train-loss
train_loss = hist.history['loss']

# plot history
plt.figure(figsize=(12, 6))
plt.plot(range(1, nb_epochs + 1), train_loss, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Loss')
plt.show()

# %% [markdown]
# # Save model

# %%
vxm_model.save_weights('AbdomenCTCT_full_model.h5')
